# %% [markdown]
# # Практикум 6. Сквозной кейс регрессии
#
# Здесь будет собран полный регрессионный сценарий: от инженерной постановки задачи прогноза до интерпретации ошибки модели и практического смысла метрик.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# Полный кейс регрессии позволяет показать, как отдельные вычислительные приемы превращаются в воспроизводимый эксперимент с понятной целевой переменной и системой оценки качества.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - будет уточнена регрессионная постановка;
# - будут сопоставлены baseline и несколько содержательных моделей;
# - будет выполнен разбор ошибок прогноза;
# - будет сделан вывод о применимости модели в инженерной задаче.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## План наполнения
#
# ### Шаг 1. Подготовка данных и постановки прогноза
# ### Шаг 2. Построение baseline и содержательных моделей
# ### Шаг 3. Сравнение `MAE`, `RMSE`, `R²`
# ### Шаг 4. Интерпретация ошибок на предметной шкале

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Как выбирать метрику, если ошибка прогноза должна интерпретироваться в физических единицах?
# 2. Какие риски возникают, если ограничиться только высоким значением `R²`?
