# %% [markdown]
# # Практикум 7. Сквозной кейс по временным рядам
#
# Этот блокнот объединит работу с временными метками, лаговыми признаками, схемой разбиения по времени и первой моделью прогноза нагрузки.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# Кейс по временным рядам нужен для того, чтобы показать отличие прогноза последовательного процесса от обычной табличной задачи. Здесь важны не только значения признаков, но и порядок наблюдений.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - будет подготовлен ряд наблюдений для прогноза;
# - будет выполнено временное разбиение без утечки будущей информации;
# - будут построены простые прогнозы и проведено их сравнение;
# - будет обсужден методический смысл лаговых и календарных признаков.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## План наполнения
#
# ### Шаг 1. Подготовка временного ряда и признаков
# ### Шаг 2. Разбиение train/test по времени
# ### Шаг 3. Базовый прогноз и первая модель
# ### Шаг 4. Интерпретация ошибок и поведения прогноза

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Почему перемешивание наблюдений особенно опасно в задачах временного прогноза?
# 2. Какие признаки, кроме лагов и часа суток, могли бы усилить этот кейс?
