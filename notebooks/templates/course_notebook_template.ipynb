# %% [markdown]
# # Практикум N. Точная тема работы
#
# Короткий подзаголовок: какой инженерный вопрос рассматривается, какие данные будут использованы и почему тема важна для анализа в электроэнергетике.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# В двух-трех абзацах объясните, какое место этот практикум занимает в общей логике курса и какую профессиональную задачу помогает понять.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - какой набор данных рассматривается;
# - какой аналитический вопрос будет решен;
# - какие результаты должен получить и интерпретировать читатель.

# %% [markdown]
# ## Данные и инструменты
#
# | Компонент | Назначение |
# | --- | --- |
# | `pandas` | чтение и преобразование данных |
# | `matplotlib` / `seaborn` | визуализация |
# | `scikit-learn` | моделирование и метрики |
# | тематический датасет | предметная основа практикума |

# %% [markdown]
# ## Ход работы
#
# ### Шаг 1. Постановка вопроса
# Кратко зафиксируйте, что именно нужно установить на этом этапе.
#
# ### Шаг 2. Подготовка данных
# Опишите, какие преобразования или проверки выполняются и зачем.
#
# ### Шаг 3. Основной аналитический шаг
# Поясните, как читатель должен понимать будущий график, метрику или модель.
#
# ### Шаг 4. Итоговая интерпретация
# Покажите, к какому содержательному выводу приводит практикум.

# %%
from pathlib import Path

import pandas as pd

from src.display_utils import display_callout, display_frame, display_metric_table, display_stage_note

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## Правило повествования
#
# После каждой существенной таблицы, визуализации или метрики дайте короткое объяснение, которое отвечает на три вопроса:
#
# - что видно из результата;
# - почему это важно для задачи;
# - к какому следующему шагу это подводит.

# %% [markdown]
# ## Итоговый вывод
#
# Заключение должно быть содержательным. Оно фиксирует не перечень выполненных операций, а полученный аналитический результат и его методический смысл.

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Как изменится результат при другой схеме предобработки?
# 2. Какие дополнительные признаки, метрики или проверки здесь уместны?
# 3. Где проходит граница между вычислительным результатом и его инженерной интерпретацией?

# %% [markdown]
# ## Источники
#
# Укажите только те датасеты, документы и методические материалы, которые реально использовались в практикуме.
