# %% [markdown]
# # Практикум 9. Итоговая самостоятельная работа
#
# Заключительный блокнот предназначен для того, чтобы собрать изученные приемы в собственное небольшое исследование на тематическом наборе данных.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# Итоговый практикум позволяет проверить, насколько уверенно читаются данные, строятся признаки, выбираются метрики и формулируются выводы без подробной пошаговой подсказки.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - будет выбрана тема и набор данных;
# - будет составлен краткий план исследования;
# - будут выполнены анализ, визуализация и модельный шаг;
# - будет подготовлено итоговое заключение по результатам самостоятельной работы.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## План наполнения
#
# ### Шаг 1. Выбор набора и постановки задачи
# ### Шаг 2. Подготовка данных и признаков
# ### Шаг 3. Анализ, визуализация и модельный шаг
# ### Шаг 4. Оформление итогового вывода

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Какой из изученных кейсов лучше всего подходит для собственной итоговой работы и почему?
# 2. Какие критерии помогут понять, что итоговый блокнот оформлен академически корректно?
