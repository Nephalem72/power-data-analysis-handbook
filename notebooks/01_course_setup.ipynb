# %% [markdown]
# # ?? ????????? 1. ?????????? ??????? ?????
#
# ?????? ??? ?????????? ? ??????, ???????????? ? ???????, ????? ?????????, ??? ??????? ?????? ????????????? ?????? ?????????. ???? ???? ??? ??????????, ????????? ??????? ????? ???? ?????? ?? ??-?? ??????, ? ??-?? ???????? ??????? ?????.

# %% [markdown]
# ## ?? ???????? ? ???????? ??????????
#
# ? ?????????????? ???????? ???????? ????? ?????????? ?? ? ??????????, ? ? ?????? ???????????????? ??????????????????: ??????? ?????? ?? ?? ??? ??????????, ????????? ???????? ?? ?? ?????? ?????????, ????????????? ???? ?????? ?? ????? ? ??????. ??????? ????????? ????????? ????? ?? ??? ????????????, ? ??? ???????? ????, ??? ??? ??????? ??????? ????????????? ?????? ? ???????????????.

# %% [markdown]
# ### ?? ???? ??????????
#
# ??????????, ??? ??????? ??????????, ?????? ????????? ? ????????? ??????????? ??????????? ????? ????? ? ????????? ??? ?????????????? ?????? ?????? ????????? ????????? ???????? ?????.

# %% [markdown]
# ### ???????????? ? ???????????? ??????????
#
# ??? ????????????????????? ???????????? ????????????????? ???????? ?????: ???? ? ?? ?? ???? ??????? ?????? ??????????? ?? ?????? ??????, ? ?????? ???????? ? ? ??????? ???????????? ??? ?????? ?????? ? ???????? ??????. ?????? ??????? ?????????? ????? ??????????????? ??? ????? ???????? ????????????.

# %% [markdown]
# ### ?? ?????? ??????????
#
# 1. ?????????? ??????????? ?????? ???????? ???????????.
# 2. ????????????? ?????? Python ? ???????? ?????????.
# 3. ????????? ??????? ???????? ????????? ???????? ?????????.
# 4. ??????? ????? ? ?????????? ????? ? ?????????? ??????.

# %% [markdown]
# ## ?? ???????????? ?????????? ? ??????
#
# | ?????????? / ????? | ?????????? |
# | --- | --- |
# | `Path` | ??????????? ????? ??????? ? ???????? ????????? |
# | `pandas` | ?????????? ??????????????? ?????? |
# | `display_utils` | ?????????? ????????????? ??????????? |
# | ????????? ???????? ??????????? | ???????? ???????????????? ???????? ??????? |

# %% [markdown]
# ## ?? ????????? ? ??????? ????????
#
# ? ???? ?????????? ?? ????????????? ??????? ???????. ???????? ???????? ?????????? ??? ??????? ????????: ???????? `docs`, `notebooks`, `data`, `src`, `kernel`, `handbook` ? ?????? ?????????, ?? ??????? ???????? ?????????? ??????.

# %% [markdown]
# ## ?? ????? ???????
#
# ### ???? 1. ??????????? ????? ???????
# ??????? ????? ??????, ?? ?????? ???????? ?????????? ?????? ???????.
#
# ### ???? 2. ???????? ??????????????? ?????????
# ????? ????? ??????????? ?????? Python ? ??????? ?????????.
#
# ### ???? 3. ???????? ????????? ???????? ?????????
# ?? ?????????????? ???? ????? ?????????, ??? ???????? ???????? ???????? ? ?????? ?????????? ?? ????????.

# %%
from pathlib import Path
import platform
import sys

import numpy as np
import pandas as pd

from src.display_utils import display_callout, display_frame, display_metric_table, display_stage_note

# ???? ??????? ?????? ?? ???????? notebooks, ?????? ??????? ????????? ?? ??????? ????
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()

display_stage_note(
    "???? 1. ?????? ???????",
    "??????? ??????????? ????, ?? ???????? ????? ????? ????????? ????????????? ?????? ?? ??????, ??????? ? ????? ???????.",
)

project_location = pd.DataFrame(
    [{"??????? ???????": str(Path.cwd()), "?????? ???????": str(PROJECT_ROOT)}]
)
display_frame(project_location, decimals=0)

# %% [markdown]
# ### ??? ?????????? ?????? ???
#
# ???? ?????? ??????? ????????? ?????????, ??????? ????? ?????????? ? ?????? ? ??????????????? ?????? ??? ?????? ?????? ?????. ??? ???????? ????? ??? ???????? ???????????, ??????? ?????? ????????? ???????? ? ????????????? ? ? ????????.

# %%
display_stage_note(
    "???? 2. ?????????????? ?????????",
    "?????? ??????????? ?????? ?????????????? ? ?????????, ????? ??????? ????? ???? ??????? ??? ?? ??????, ??? ? ?????????? ?????????? ???????.",
)

# ?????? ???????? ? ????? ? ???? ?????????? ???????
environment_info = pd.DataFrame(
    [
        {
            "Python": sys.version.split()[0],
            "?????????": platform.platform(),
            "pandas": pd.__version__,
            "NumPy": np.__version__,
        }
    ]
)
display_frame(environment_info, decimals=0)

# %% [markdown]
# ### ??? ???????????????? ??????? ?????????
#
# ???? ???? ?????????? ????? ??? ?? ???????????, ?????? ????? ??? ????? ???????????? ????????. ???????? ? ??????? ????????? ????? ?????? ?????? ??????, ?????????? ???????? ? ????????? ????????? ???????. ??????? ????? ??????? ?????? ?????? ?????????????????? ?????????, ? ?? ???????????? ???????????.

# %%
display_stage_note(
    "???? 3. ????????? ???????? ?????????",
    "?? ???? ????? ????????, ???????? ?? ????????, ??????? ????????? ???????, ????????, ??????, ???????? ??? ? ??????? ????.",
)

# ????????? ???????? ????????, ??? ??????? ???? ?????? ???????????
project_dirs = [
    PROJECT_ROOT / "docs",
    PROJECT_ROOT / "notebooks",
    PROJECT_ROOT / "data",
    PROJECT_ROOT / "src",
    PROJECT_ROOT / "kernel",
    PROJECT_ROOT / "handbook",
]

status = pd.DataFrame(
    {
        "???????": [str(path.relative_to(PROJECT_ROOT)) for path in project_dirs],
        "??????": [path.exists() for path in project_dirs],
    }
)
display_frame(status, decimals=0)

display_metric_table(
    {
        "????????? ?????????": float(len(project_dirs)),
        "????????? ???????": float(status["??????"].sum()),
        "????????? ???????????": float((~status["??????"]).sum()),
    },
    decimals=0,
)

# %% [markdown]
# ### ?????? ???????? ????????? ??? ?????
#
# ??????? ???????, ???????? ? ?????? ?????? ???????????? ?? ??? ????????? ?????????, ? ??? ?????? ????????. ???? ????????? ???? ?? ???? ?? ???????? ?????????, ??????????? ??????????????? ?????? ?????: ???-?? ?? ????????? ??????, ???-?? ?? ????????? PDF, ? ???-?? ???????? ?????? ?? ?????????.

# %%
missing_catalogs = status.loc[~status["??????"], "???????"].tolist()

if missing_catalogs:
    display_callout(
        "????? ??????? ???????????",
        "?? ??????? ????????: " + ", ".join(missing_catalogs) + ". ????? ????????? ? ????????? ???????? ?? ????? ????????????.",
        tone="warning",
    )
else:
    display_callout(
        "????? ??????? ?????????",
        "?????? ???????, ????????? ? ????????? ????????? ???????????. ????? ?????????? ? ?????? ? ??????? ? ??????????? ????????????? ???????????.",
        tone="success",
    )

# %% [markdown]
# ## ?? ???????????? ????? ??????????
#
# ????? ????? ???????? ?????????? ????, ??? ?????? ? ????????? ????????? ????? ??????? ??? ? ??????? ??? ????????, ? ?? ? ?????????? ??????? ?????. ??? ??????? ?????? ???????????????? ? ?????? ?????????? ???????? ??????? ????? ??????????.

# %% [markdown]
# ## ?? ? ???? ???????? ???? ???????????????? ????
#
# ?????????? ????? ??????????? ?????? ????? ?????????? ??????? ??????. ??? ????????? ??????? ??????, ? ???????? ???????? ????? ????? ???????? ?????, ????????? ???????, ??????????? ?????? ? ?????????? ????????? ???????.

# %% [markdown]
# ## ? ??????? ??? ??????????????? ??????
#
# 1. ????? ?????? ???? ????? ????????? ??? ??????? ????????? ?? ????????????? ?????????
# 2. ?????? ????????? Jupyter-???? ????????, ??? ?????? ? ????????? ????? ??????????
# 3. ????? ???????? ? ????? ?????? ?? ????????????? ???????? ? ????????????????? ?????????

# %% [markdown]
# ## ?? ?????????
#
# 1. [JupyterLab Overview](https://jupyterlab.readthedocs.io/en/stable/getting_started/overview.html)
# 2. [Jupyter Notebook documentation](https://jupyter-notebook.readthedocs.io/en/stable/notebook.html)
# 3. [?????????? ?? ???????? ????](https://github.com/Nephalem72/power-data-analysis-handbook/blob/main/docs/kernel-installation.md)
