# %% [markdown]
# # ????? ?????? ? ??????????????? ??????
#
# ???? ??????? ?????? ? ?????? ?????? ??????? ? ????? ??? ???????? ?????????, ????????? ??????? ? ??????? ????????? ?????? ? Jupyter.

# %% [markdown]
# ## ???? ? ????????? ??????????
#
# ????? ?????????? ???????? ???????? ??????:
#
# - ????????, ??? ??????? ???????????;
# - ????? ????????? ??????? ?????????? ? ?????????;
# - ????????? ???? ?????????, ??????, ???????????? ? ???????????????? ????;
# - ????? ??????? ????? ????? ??? ?????????? ???????? ?????.

# %% [markdown]
# ## ??????? ???????? ??????
#
# ? ???? ???????? ?? ???????? ?????? ? ?? ???????? ?????????? ??????. ???? ??????? ? ???, ????? ????????? ? ????????? ??????? ??????, ?? ??????? ????? ????? ??????????? ??? ??????? ?? ??????? ?????? ? ?????????????????.

# %% [markdown]
# ## ???????????? ?????????? ? ????? ??? ?????
#
# | ?????????? | ?????????? |
# | --- | --- |
# | pathlib | ?????? ? ?????? ? ?????????? ??????? |
# | sys / platform | ???????? ?????? Python ? ?????????? ????? |
# | pandas / numpy | ??????? ??????????, ??????? ????? ?????????????? ? ?????????? |
# | IPython.display | ?????????? ????????????? ??????????? ????? ? ???????? |

# %% [markdown]
# ## ???????? ? ???????? ??????
#
# ? ???????????? ???????? ??????? ?????? ?? ?????????. ???????? ?????? ???????? ? ???? ????????? ??????? ? ?????????? ????????? ? ?????????? ????????? ????????.

# %% [markdown]
# ## ????? ???????
#
# ### 1. ???????? ??????? ??????????
# ??????????, ?? ????? ????? ??????? ??????? ? ??? ????????? ?????? ???????.
#
# ### 2. ???????? Python ? ?????????
# ??????????, ??? ???????? ??????? ??????????? ?????.
#
# ### 3. ???????? ????????? ???????
# ?????????, ??? ???????? ????????????? ? ????????? `notebooks/`, `data/`, `docs/`, `src/`.
#
# ### 4. ???????? ?????????????
# ?????????, ??? ?????? ????????????????? ????? ? ?????????? ??????.

# %%
from pathlib import Path
import platform
import sys

import numpy as np
import pandas as pd
from IPython.display import Markdown, display

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## ?????????????
#
# ???? ???? ????????? ?? ?????? ???????????, ?????? ??????? ??????? ? ????????? ????????? ???????. ???? ???? ????? ? ?????? ??????????, ?????????? ?????? ? ?????????????? ?????? ????? ?????? ??????.

# %%
environment_info = {
    "python_version": sys.version.split()[0],
    "platform": platform.platform(),
    "pandas": pd.__version__,
    "numpy": np.__version__,
}

pd.DataFrame([environment_info])

# %% [markdown]
# ## ?????????????
#
# ??? ??????? ??????????, ??? ??????? ?????????? ????????. ? ??????????? ?????? ?????? ???????????? ????? ???????????, ?? ?????? ??? ?????? ?????????? ??????????? ?????? ?????.

# %%
project_dirs = [
    PROJECT_ROOT / "notebooks",
    PROJECT_ROOT / "data",
    PROJECT_ROOT / "docs",
    PROJECT_ROOT / "src",
    PROJECT_ROOT / "tasks",
]

status = pd.DataFrame(
    {
        "path": [str(p.relative_to(PROJECT_ROOT)) for p in project_dirs],
        "exists": [p.exists() for p in project_dirs],
    }
)
status

# %% [markdown]
# ## ?????????????
#
# ???? ??? ???????? ???????? ??????????, ????????? ??????? ??????? ?????????. ??? ?????, ?????? ??? ? ????? ??????, ???, ?????? ? ??????? ????? ???????????? ?? ?????? ?????????, ? ?? ??????? ? ????? ????????.

# %%
display(Markdown(
    "### ??????? ????
"
    "- ??????????? ??????.
"
    "- ??????? ?????????? ????????.
"
    "- ????????? ??????? ?????? ??? ????????? ???????? ?????."
))

# %% [markdown]
# ## ???????? ??????
#
# - Jupyter-??????? ? ???? ??????? ??????????????? ??? ??????????? ??????? ????????.
# - ????????????????? ?????????????? ?? ????? ??????, ? ???? ?????????? ???????????.
# - ????? ??????? ??????? ?????? ????? ????????? ?????????, ???? ? ??????? ???????????.

# %% [markdown]
# ## ??????? ??? ??????? ??? ??????????????? ??????
#
# 1. ?????? ? ??????? ??????? ???????? `data/raw` ?? `data/processed`?
# 2. ??? ??????????, ???? ??????? ????????? ?? ?? ????? ??????? ? ?? ?? ???????? `notebooks/`?
# 3. ????? ?????????? ?? ?? ???????? ? ????????? ??? ??????????? ???? ? ???????

# %% [markdown]
# ## ?????????
#
# 1. [JupyterLab Overview](https://jupyterlab.readthedocs.io/en/stable/getting_started/overview.html)
# 2. [Jupyter Notebook documentation](https://jupyter-notebook.readthedocs.io/en/stable/notebook.html)
# 3. [README ???????????](https://github.com/Nephalem72/power-data-analysis-handbook/blob/main/README.md)
