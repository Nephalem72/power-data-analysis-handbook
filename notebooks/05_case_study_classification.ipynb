# %% [markdown]
# # Практикум 5. Сквозной кейс классификации
#
# В этом блокноте будет собран полный цикл классификационной задачи: от выбора признаков и схемы разбиения до интерпретации метрик и выводов о пригодности модели.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# Кейс по классификации нужен для того, чтобы соединить ранние разделы курса в одну последовательную практику: чтение данных, контроль качества, подготовку признаков, обучение модели и оценку результата.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - будет уточнена постановка классификационной задачи;
# - будут выбраны признаки и целевая метка;
# - будут сопоставлены несколько моделей и метрик;
# - будет сформулирован содержательный вывод по результатам классификации.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## План наполнения
#
# ### Шаг 1. Формулировка классификационной постановки
# ### Шаг 2. Подготовка признаков и разбиение
# ### Шаг 3. Обучение и сравнение моделей
# ### Шаг 4. Интерпретация матрицы ошибок и метрик

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Какие признаки потенциально наиболее важны для классификации устойчивости режима?
# 2. Почему одной метрики `accuracy` недостаточно для полного анализа качества?
