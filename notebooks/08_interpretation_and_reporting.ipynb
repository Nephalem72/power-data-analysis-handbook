# %% [markdown]
# # Практикум 8. Интерпретация результатов и подготовка аналитического отчета
#
# На этом этапе отдельные вычислительные результаты должны быть собраны в цельное аналитическое сообщение: что именно удалось установить, какие ограничения есть у модели и как корректно оформить выводы для читателя.

# %% [markdown]
# ## Зачем выполняется эта работа
#
# Даже удачный расчет не имеет ценности, если его невозможно объяснить. Практикум нужен для перехода от набора графиков и метрик к строгому текстовому заключению.

# %% [markdown]
# ## Что будет сделано в практикуме
#
# - будут отобраны ключевые таблицы, метрики и графики;
# - будут сформулированы промежуточные и итоговые выводы;
# - будет показано, как связать блокнот с текстом пособия и отчетом;
# - будет собрана основа для краткой аналитической записки.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# ## План наполнения
#
# ### Шаг 1. Отбор результатов
# ### Шаг 2. Формулировка интерпретаций
# ### Шаг 3. Сборка выводов и ограничений
# ### Шаг 4. Подготовка текста для отчета или пособия

# %% [markdown]
# ## Вопросы для самостоятельной работы
#
# 1. Почему нельзя переносить численные метрики в отчет без текстовой интерпретации?
# 2. Какие результаты обязательно должны попасть в итоговый аналитический текст, а какие можно оставить в блокноте?
